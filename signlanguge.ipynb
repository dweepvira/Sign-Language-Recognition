# %%
import cv2
import os
import mediapipe as mp
import numpy as np
import time
from matplotlib import pyplot as plt

# %%
sequences,labels=[],[]
for action in actions:
    for sequence in range(no_sequences):
        window=[]
        for frame_num in range(sequence_length):
            res=np.load(os.path.join(DATA_PATH,action,str(sequence),"{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X=np.array(sequences)

# %%
y=to_categorical(labels).astype(int)

# %%
X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=0.05)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense
from tensorflow.keras .callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback= TensorBoard(log_dir=log_dir)

# %%
model=Sequential()
model.add(LSTM(64,return_sequences=True,activation='relu',input_shape=(30,1662)))
model.add(LSTM(128,return_sequences=True,activation='relu'))
model.add(LSTM(64,return_sequences=False,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(actions.shape[0],activation='softmax'))

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['categorical_accuracy'])

# %%
model.fit(X_train,y_train,epochs=150,callbacks=[tb_callback])
# Out:
# Epoch 1/150
# 3/3 [==============================] - 1s 226ms/step - loss: 1.3986 - categorical_accuracy: 0.3882
# Epoch 2/150
# 3/3 [==============================] - 0s 104ms/step - loss: 1.4529 - categorical_accuracy: 0.5059
# Epoch 3/150
# 3/3 [==============================] - 0s 99ms/step - loss: 1.2692 - categorical_accuracy: 0.6118
# Epoch 4/150
# 3/3 [==============================] - 0s 121ms/step - loss: 1.0751 - categorical_accuracy: 0.4471
# Epoch 5/150
# 3/3 [==============================] - 0s 93ms/step - loss: 1.2679 - categorical_accuracy: 0.4118
# Epoch 6/150
# 3/3 [==============================] - 0s 92ms/step - loss: 1.4831 - categorical_accuracy: 0.4118
# Epoch 7/150
# 3/3 [==============================] - 0s 95ms/step - loss: 1.7463 - categorical_accuracy: 0.3765
# Epoch 8/150
# 3/3 [==============================] - 0s 103ms/step - loss: 1.4156 - categorical_accuracy: 0.3765
# Epoch 9/150
# 3/3 [==============================] - 0s 90ms/step - loss: 1.4588 - categorical_accuracy: 0.4118
# Epoch 10/150
# 3/3 [==============================] - 0s 88ms/step - loss: 1.3290 - categorical_accuracy: 0.4118
# Epoch 11/150
# 3/3 [==============================] - 0s 87ms/step - loss: 1.2124 - categorical_accuracy: 0.2706
# Epoch 12/150
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0669 - categorical_accuracy: 0.4471
# Epoch 13/150
# 3/3 [==============================] - 0s 91ms/step - loss: 1.1107 - categorical_accuracy: 0.5059
# Epoch 14/150
# 3/3 [==============================] - 0s 109ms/step - loss: 1.1878 - categorical_accuracy: 0.4471
# Epoch 15/150
# 3/3 [==============================] - 0s 125ms/step - loss: 1.2127 - categorical_accuracy: 0.5529
# Epoch 16/150
# 3/3 [==============================] - 0s 103ms/step - loss: 1.2423 - categorical_accuracy: 0.4471
# Epoch 17/150
# 3/3 [==============================] - 0s 98ms/step - loss: 1.1356 - categorical_accuracy: 0.4706
# Epoch 18/150
# 3/3 [==============================] - 0s 102ms/step - loss: 0.9989 - categorical_accuracy: 0.5647
# Epoch 19/150
# 3/3 [==============================] - 0s 108ms/step - loss: 0.9527 - categorical_accuracy: 0.6000
# Epoch 20/150
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0606 - categorical_accuracy: 0.4353
# Epoch 21/150
# 3/3 [==============================] - 0s 87ms/step - loss: 1.2738 - categorical_accuracy: 0.4471
# Epoch 22/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9938 - categorical_accuracy: 0.4706
# Epoch 23/150
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0779 - categorical_accuracy: 0.4588
# Epoch 24/150
# 3/3 [==============================] - 0s 104ms/step - loss: 1.0331 - categorical_accuracy: 0.4941
# Epoch 25/150
# 3/3 [==============================] - 0s 107ms/step - loss: 0.9639 - categorical_accuracy: 0.5529
# Epoch 26/150
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0227 - categorical_accuracy: 0.6118
# Epoch 27/150
# 3/3 [==============================] - 0s 93ms/step - loss: 0.9627 - categorical_accuracy: 0.5765
# Epoch 28/150
# 3/3 [==============================] - 0s 97ms/step - loss: 0.9630 - categorical_accuracy: 0.5765
# Epoch 29/150
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0077 - categorical_accuracy: 0.4824
# Epoch 30/150
# 3/3 [==============================] - 0s 100ms/step - loss: 1.1964 - categorical_accuracy: 0.4706
# Epoch 31/150
# 3/3 [==============================] - 0s 100ms/step - loss: 0.9946 - categorical_accuracy: 0.5529
# Epoch 32/150
# 3/3 [==============================] - 0s 108ms/step - loss: 1.0338 - categorical_accuracy: 0.5529
# Epoch 33/150
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1028 - categorical_accuracy: 0.6000
# Epoch 34/150
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0411 - categorical_accuracy: 0.4941
# Epoch 35/150
# 3/3 [==============================] - 0s 99ms/step - loss: 0.8672 - categorical_accuracy: 0.5294
# Epoch 36/150
# 3/3 [==============================] - 0s 126ms/step - loss: 0.9560 - categorical_accuracy: 0.6118
# Epoch 37/150
# 3/3 [==============================] - 0s 100ms/step - loss: 0.8671 - categorical_accuracy: 0.6706
# Epoch 38/150
# 3/3 [==============================] - 0s 98ms/step - loss: 0.9126 - categorical_accuracy: 0.5765
# Epoch 39/150
# 3/3 [==============================] - 0s 103ms/step - loss: 0.8581 - categorical_accuracy: 0.6471
# Epoch 40/150
# 3/3 [==============================] - 0s 94ms/step - loss: 0.9122 - categorical_accuracy: 0.6471
# Epoch 41/150
# 3/3 [==============================] - 0s 98ms/step - loss: 0.9539 - categorical_accuracy: 0.6235
# Epoch 42/150
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0689 - categorical_accuracy: 0.4941
# Epoch 43/150
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0409 - categorical_accuracy: 0.5294
# Epoch 44/150
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0429 - categorical_accuracy: 0.4235
# Epoch 45/150
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0769 - categorical_accuracy: 0.4353
# Epoch 46/150
# 3/3 [==============================] - 0s 103ms/step - loss: 0.9402 - categorical_accuracy: 0.5059
# Epoch 47/150
# 3/3 [==============================] - 0s 109ms/step - loss: 0.8723 - categorical_accuracy: 0.6588
# Epoch 48/150
# 3/3 [==============================] - 0s 97ms/step - loss: 0.8938 - categorical_accuracy: 0.6941
# Epoch 49/150
# 3/3 [==============================] - 0s 99ms/step - loss: 0.9007 - categorical_accuracy: 0.6118
# Epoch 50/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.8793 - categorical_accuracy: 0.6000
# Epoch 51/150
# 3/3 [==============================] - 0s 94ms/step - loss: 1.1560 - categorical_accuracy: 0.5059
# Epoch 52/150
# 3/3 [==============================] - 0s 101ms/step - loss: 1.1962 - categorical_accuracy: 0.5412
# Epoch 53/150
# 3/3 [==============================] - 0s 106ms/step - loss: 1.0245 - categorical_accuracy: 0.4824
# Epoch 54/150
# 3/3 [==============================] - 0s 101ms/step - loss: 0.8718 - categorical_accuracy: 0.6235
# Epoch 55/150
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0576 - categorical_accuracy: 0.6471
# Epoch 56/150
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0862 - categorical_accuracy: 0.6706
# Epoch 57/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9102 - categorical_accuracy: 0.6941
# Epoch 58/150
# 3/3 [==============================] - 0s 128ms/step - loss: 1.0810 - categorical_accuracy: 0.6235
# Epoch 59/150
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1987 - categorical_accuracy: 0.5412
# Epoch 60/150
# 3/3 [==============================] - 0s 104ms/step - loss: 1.2085 - categorical_accuracy: 0.4824
# Epoch 61/150
# 3/3 [==============================] - 0s 148ms/step - loss: 1.1628 - categorical_accuracy: 0.5529
# Epoch 62/150
# 3/3 [==============================] - 0s 125ms/step - loss: 1.2340 - categorical_accuracy: 0.4471
# Epoch 63/150
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0533 - categorical_accuracy: 0.4941
# Epoch 64/150
# 3/3 [==============================] - 0s 93ms/step - loss: 0.8445 - categorical_accuracy: 0.6000
# Epoch 65/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.8680 - categorical_accuracy: 0.6235
# Epoch 66/150
# 3/3 [==============================] - 0s 106ms/step - loss: 0.8137 - categorical_accuracy: 0.6706
# Epoch 67/150
# 3/3 [==============================] - 0s 83ms/step - loss: 0.7838 - categorical_accuracy: 0.6706
# Epoch 68/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.7803 - categorical_accuracy: 0.6706
# Epoch 69/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.8335 - categorical_accuracy: 0.6706
# Epoch 70/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9076 - categorical_accuracy: 0.5529
# Epoch 71/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.9521 - categorical_accuracy: 0.6353
# Epoch 72/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.8879 - categorical_accuracy: 0.6235
# Epoch 73/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.8933 - categorical_accuracy: 0.6706
# Epoch 74/150
# 3/3 [==============================] - 0s 81ms/step - loss: 0.8624 - categorical_accuracy: 0.6471
# Epoch 75/150
# 3/3 [==============================] - 0s 81ms/step - loss: 1.0531 - categorical_accuracy: 0.5529
# Epoch 76/150
# 3/3 [==============================] - 0s 80ms/step - loss: 0.8686 - categorical_accuracy: 0.6588
# Epoch 77/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.9801 - categorical_accuracy: 0.5765
# Epoch 78/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8486 - categorical_accuracy: 0.6000
# Epoch 79/150
# 3/3 [==============================] - 0s 81ms/step - loss: 0.9751 - categorical_accuracy: 0.5882
# Epoch 80/150
# 3/3 [==============================] - 0s 103ms/step - loss: 0.7841 - categorical_accuracy: 0.7059
# Epoch 81/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8264 - categorical_accuracy: 0.6353
# Epoch 82/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.9207 - categorical_accuracy: 0.6353
# Epoch 83/150
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0451 - categorical_accuracy: 0.5882
# Epoch 84/150
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1962 - categorical_accuracy: 0.4941
# Epoch 85/150
# 3/3 [==============================] - 0s 80ms/step - loss: 1.1041 - categorical_accuracy: 0.4824
# Epoch 86/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8648 - categorical_accuracy: 0.6118
# Epoch 87/150
# 3/3 [==============================] - 0s 92ms/step - loss: 0.9777 - categorical_accuracy: 0.6353
# Epoch 88/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.7516 - categorical_accuracy: 0.6706
# Epoch 89/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.8968 - categorical_accuracy: 0.6235
# Epoch 90/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.9390 - categorical_accuracy: 0.6000
# Epoch 91/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.9009 - categorical_accuracy: 0.6118
# Epoch 92/150
# 3/3 [==============================] - 0s 100ms/step - loss: 1.1650 - categorical_accuracy: 0.5176
# Epoch 93/150
# 3/3 [==============================] - 0s 80ms/step - loss: 1.3168 - categorical_accuracy: 0.5294
# Epoch 94/150
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1348 - categorical_accuracy: 0.4706
# Epoch 95/150
# 3/3 [==============================] - 0s 101ms/step - loss: 1.4674 - categorical_accuracy: 0.4471
# Epoch 96/150
# 3/3 [==============================] - 0s 80ms/step - loss: 1.3583 - categorical_accuracy: 0.4235
# Epoch 97/150
# 3/3 [==============================] - 0s 82ms/step - loss: 1.1889 - categorical_accuracy: 0.4471
# Epoch 98/150
# 3/3 [==============================] - 0s 85ms/step - loss: 1.0280 - categorical_accuracy: 0.5647
# Epoch 99/150
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0876 - categorical_accuracy: 0.5176
# Epoch 100/150
# 3/3 [==============================] - 0s 79ms/step - loss: 0.8642 - categorical_accuracy: 0.7176
# Epoch 101/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.9188 - categorical_accuracy: 0.6471
# Epoch 102/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.7369 - categorical_accuracy: 0.6941
# Epoch 103/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.7776 - categorical_accuracy: 0.7294
# Epoch 104/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7305 - categorical_accuracy: 0.7294
# Epoch 105/150
# 3/3 [==============================] - 0s 92ms/step - loss: 0.6824 - categorical_accuracy: 0.7176
# Epoch 106/150
# 3/3 [==============================] - 0s 83ms/step - loss: 0.7544 - categorical_accuracy: 0.6824
# Epoch 107/150
# 3/3 [==============================] - 0s 112ms/step - loss: 0.7254 - categorical_accuracy: 0.7529
# Epoch 108/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.6645 - categorical_accuracy: 0.7529
# Epoch 109/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.7518 - categorical_accuracy: 0.7412
# Epoch 110/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.7053 - categorical_accuracy: 0.7294
# Epoch 111/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.7596 - categorical_accuracy: 0.7059
# Epoch 112/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.7337 - categorical_accuracy: 0.6824
# Epoch 113/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.8837 - categorical_accuracy: 0.6353
# Epoch 114/150
# 3/3 [==============================] - 0s 80ms/step - loss: 0.7840 - categorical_accuracy: 0.6824
# Epoch 115/150
# 3/3 [==============================] - 0s 80ms/step - loss: 0.9062 - categorical_accuracy: 0.5765
# Epoch 116/150
# 3/3 [==============================] - 0s 81ms/step - loss: 0.8524 - categorical_accuracy: 0.7294
# Epoch 117/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.7350 - categorical_accuracy: 0.7529
# Epoch 118/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.7490 - categorical_accuracy: 0.6471
# Epoch 119/150
# 3/3 [==============================] - 0s 111ms/step - loss: 0.8646 - categorical_accuracy: 0.5529
# Epoch 120/150
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0679 - categorical_accuracy: 0.5882
# Epoch 121/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.8462 - categorical_accuracy: 0.6941
# Epoch 122/150
# 3/3 [==============================] - 0s 80ms/step - loss: 0.6760 - categorical_accuracy: 0.7529
# Epoch 123/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7646 - categorical_accuracy: 0.7059
# Epoch 124/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.7839 - categorical_accuracy: 0.6588
# Epoch 125/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.8661 - categorical_accuracy: 0.6706
# Epoch 126/150
# 3/3 [==============================] - 0s 83ms/step - loss: 1.2232 - categorical_accuracy: 0.4706
# Epoch 127/150
# 3/3 [==============================] - 0s 92ms/step - loss: 0.9838 - categorical_accuracy: 0.5765
# Epoch 128/150
# 3/3 [==============================] - 0s 80ms/step - loss: 0.8332 - categorical_accuracy: 0.6706
# Epoch 129/150
# 3/3 [==============================] - 0s 83ms/step - loss: 0.8929 - categorical_accuracy: 0.6824
# Epoch 130/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.8804 - categorical_accuracy: 0.5529
# Epoch 131/150
# 3/3 [==============================] - 0s 111ms/step - loss: 0.7735 - categorical_accuracy: 0.6471
# Epoch 132/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9684 - categorical_accuracy: 0.6353
# Epoch 133/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.8017 - categorical_accuracy: 0.5529
# Epoch 134/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.9127 - categorical_accuracy: 0.7176
# Epoch 135/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.9089 - categorical_accuracy: 0.6706
# Epoch 136/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6974 - categorical_accuracy: 0.6941
# Epoch 137/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7983 - categorical_accuracy: 0.6824
# Epoch 138/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.9572 - categorical_accuracy: 0.6118
# Epoch 139/150
# 3/3 [==============================] - 0s 93ms/step - loss: 0.8462 - categorical_accuracy: 0.6353
# Epoch 140/150
# 3/3 [==============================] - 0s 81ms/step - loss: 0.9572 - categorical_accuracy: 0.6706
# Epoch 141/150
# 3/3 [==============================] - 0s 95ms/step - loss: 0.8935 - categorical_accuracy: 0.6000
# Epoch 142/150
# 3/3 [==============================] - 0s 108ms/step - loss: 0.8691 - categorical_accuracy: 0.6471
# Epoch 143/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7376 - categorical_accuracy: 0.6824
# Epoch 144/150
# 3/3 [==============================] - 0s 81ms/step - loss: 0.8584 - categorical_accuracy: 0.6118
# Epoch 145/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.8863 - categorical_accuracy: 0.6000
# Epoch 146/150
# 3/3 [==============================] - 0s 81ms/step - loss: 0.9959 - categorical_accuracy: 0.5765
# Epoch 147/150
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0762 - categorical_accuracy: 0.5882
# Epoch 148/150
# 3/3 [==============================] - 0s 81ms/step - loss: 1.3031 - categorical_accuracy: 0.5882
# Epoch 149/150
# 3/3 [==============================] - 0s 85ms/step - loss: 1.1660 - categorical_accuracy: 0.4588
# Epoch 150/150
# 3/3 [==============================] - 0s 83ms/step - loss: 0.9784 - categorical_accuracy: 0.6000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 64)            442112
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 128)           98816
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = model.predict(X_test)

# %%
model.save('action.h5')

# %%
from sklearn.metrics import multilabel_confusion_matrix,accuracy_score

# %%
yhat=model.predict(X_test)

# %%
ytrue=np.argmax(y_test,axis=1).tolist()
yhat=np.argmax(yhat,axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue,yhat)
accuracy_score(ytrue,yhat)
# Out:
# 0.4

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# Cell In[38], line 5, in prob_viz(res, actions, input_frame, colors)
#       3 output_frame = input_frame.copy()
#       4 for num, prob in enumerate(res):
# ----> 5     cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#       6     cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       8 return output_frame
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('Isolated Sign Language', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# I love you
